# %%
import matplotlib.pyplot as plt

data = {
    'Range': ['71-72', '73-74', '75-76', '77-78', '79-80', '81-82', '83-84', '85-86', '87-88', '89-90', '91-92', '93-94', '95-96', '97-98', '99-100'],
    'Value1': [0.07, 0.51, 2.15, 5.71, 9.76, 11.9, 10.78, 7.7, 4.39, 2.06, 0.8, 0.25, 0.07, 0.02, 0.01],
    'Value2': [0.01, 0.08, 0.34, 1.06, 2.57, 4.78, 6.88, 7.84, 7.47, 5.76, 3.7, 1.82, 0.72, 0.21, 0.03]
}

# 提取数据
range_labels = data['Range']
value1 = data['Value1']
value2 = data['Value2']

# 绘制柱状图
plt.figure(figsize=(10, 6))
plt.bar(range_labels, value1, label='Value1')
plt.bar(range_labels, value2, label='Value2')
plt.xlabel('Range')
plt.ylabel('Percentage')
plt.title('Data Distribution')
plt.legend()

# 展示图表
plt.show()
